# %% [markdown]
# Basic Creation of Regression using Tenserflow.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
X = (np.random.randn(100)*10).astype(np.int16)
print(X)
y=(3*X+5).astype(np.int16)
print(y)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
X_train=X_train.reshape(-1,1)
X_test=X_train.reshape(-1,1)
y_train=X_train.reshape(-1,1)
y_test=X_train.reshape(-1,1)
# Out:
# [-29  -8  -7   0  -3  -3  -8   3  16  11  -1  -6 -16   4 -11   0   0 -20
#  -14  -1  19 -12  -4   6   5  -3   4  -8  -8  10   5   5  -8 -12 -20   0
#    2 -26  -5   9   0   2   3 -12  12  14   5  -7  -7  18  19   7  13   0
#  -10   5 -10  13  -9  15 -20 -12  -3  -1   6 -13 -20  14  20  12 -13  -2
#    0   3   0   4  -6   4   0 -20  -3   0  -5  -8   6  -2   0  13   4  -1
#    0 -22  -3  -5   0  -2  -1   9   1   6]
# [-82 -19 -16   5  -4  -4 -19  14  53  38   2 -13 -43  17 -28   5   5 -55
#  -37   2  62 -31  -7  23  20  -4  17 -19 -19  35  20  20 -19 -31 -55   5
#   11 -73 -10  32   5  11  14 -31  41  47  20 -16 -16  59  62  26  44   5
#  -25  20 -25  44 -22  50 -55 -31  -4   2  23 -34 -55  47  65  41 -34  -1
#    5  14   5  17 -13  17   5 -55  -4   5 -10 -19  23  -1   5  44  17   2
#    5 -61  -4 -10   5  -1   2  32   8  23]

# %%
plt.plot(X,y, 'go')
plt.show()

# %%
tf.random.set_seed(10)
model=tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=['mae'])
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4631 - mae: 7.4631
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4896 - mae: 5.4896
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5159 - mae: 3.5159
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5424 - mae: 1.5424
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2353 - mae: 0.2353
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4723 - mae: 0.4723
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2413 - mae: 0.2413
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4723 - mae: 0.4723
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2413 - mae: 0.2413
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4723 - mae: 0.4723

# %%
# print(X_test)
# print(y_test)
plt.plot(X_test,y_test, 'bo',label='Original')
plt.plot(X_test,model.predict(X_test), 'ro',label='Predicted')
plt.legend()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                     │ (None, 1)                   │               2 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4 (20.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)
